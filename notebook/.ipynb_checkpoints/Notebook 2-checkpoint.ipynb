# %% [markdown]
# # Desafio Forecast - Parte 2
#
# ## Autor: Raphael Paes Pinto

# %%
# Instalação de pacotes
#!pip install keras
#! pip install tensorflow
#!pip install pmdarima

# %%
# Pacotes

import pandas as pd
from pandas import Series
import numpy as np
from numpy import mean
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import datetime

import warnings
warnings.simplefilter("ignore")

from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import pmdarima as pm

from sklearn.preprocessing import StandardScaler

from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import GRU

# configurando pros gráficos ficarem ajustados
plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (16, 8)

# %% [markdown]
# #### Base de dados

# %%
# Arquivo com a serie temporal
df = pd.read_csv(r'C:\Users\rapha\Documents\desafio_forecast\dataset\serie\serie_vitimas_desafio.csv', sep = ';', decimal = '.')
#df = pd.read_csv(r'C:\Users\raphael.pinto\Documents\desafio_forecast\dataset\serie\serie_vitimas_desafio.csv', sep = ';', decimal = '.')
df.head()
# Out:
#          data  vitimas_total
# 0  2015-06-01            6.0
# 1  2015-06-02            8.0
# 2  2015-06-03            4.0
# 3  2015-06-04            4.0
# 4  2015-06-05            8.0

# %%
df.dtypes
# Out:
# data              object
# vitimas_total    float64
# dtype: object

# %%
# No decorrer do código serão sugeridos alguns modelos e métricas para mensurar os resultados

# %%
# Para facilitar os próximos passos e seguindo as instruções do desafios:
# separação do material em treino (train) e teste (test)
train = df[(df['data'] >= '2015-06-01') & (df['data'] <= '2018-12-31')]
train['data'] =  pd.to_datetime(train['data'], format='%Y-%m-%d')

test = df[(df['data'] >= '2019-01-01') ]
test['data'] =  pd.to_datetime(test['data'], format='%Y-%m-%d')

# %%
# Checando se ficou separado corretamente
print(min(train['data']), max(train['data']), min(test['data']), max(test['data']) )
# Out:
# 2015-06-01 00:00:00 2018-12-31 00:00:00 2019-01-01 00:00:00 2019-12-31 00:00:00

# %% [markdown]
# ### Modelo 1 - Suavização Exponencial Simples
#
# * A suavização exponencial simples, com o próprio nome diz, é o caso particular mais simples de suavização exponencial. Esse tipo de modelo serve para quando não existe nenhum padrão claro de sazonalidade ou tendência na série. (https://blog.curso-r.com/posts/2019-02-10-ses/)

# %%
# Definindo o index como cada dia da série, mas sem perder o dado inicial (train)
trainD = train.set_index('data')

# Treinando o modelo de suavização exponencial simples. Com base em testes feitos a constante de suavização que minimiza os erros é a de valor 0.111.
model1 = SimpleExpSmoothing(trainD).fit()

# Previsões
modelo1 = model1.forecast(len(test))
modelo1
# Out:
# 2019-01-01    6.340655
# 2019-01-02    6.340655
# 2019-01-03    6.340655
# 2019-01-04    6.340655
# 2019-01-05    6.340655
#                 ...
# 2019-12-27    6.340655
# 2019-12-28    6.340655
# 2019-12-29    6.340655
# 2019-12-30    6.340655
# 2019-12-31    6.340655
# Freq: D, Length: 365, dtype: float64

# %%
# Métricas para mensurar o modelo
print('Erro médio absoluto (MSE):',
      round(mean_absolute_error(test.set_index('data'), modelo1), 3))
print('Raiz do erro médio quadrado (RMSE):',
      round(mean_squared_error(test.set_index('data'), modelo1)**0.5, 3))
print('Soma quadratica dos erros (SSE):',
      round(np.sum((modelo1.values - test.set_index('data').values)**2), 3))
print('Erro medio percentual absoluto (MAPE):',
      np.mean(np.abs((test.set_index('data').values - modelo1.values)/test.set_index('data').values))*100)
# Out:
# Erro médio absoluto (MSE): 2.631
# Raiz do erro médio quadrado (RMSE): 3.345
# Soma quadratica dos erros (SSE): 1490702.708
# Erro medio percentual absoluto (MAPE): inf

# %%
plt.plot(test.set_index('data'), color = 'blue', label = 'Real')
plt.plot(modelo1, color = 'red', label = 'Previsto')
plt.title('Modelo 1 - Suavização Exponencial Simples')
plt.xlabel('Tempo')
plt.ylabel('Vitimas de acidentes')
plt.legend()
plt.show()

# %% [markdown]
# ### Modelo 2 - Suavização de Media Móvel
#
# * A suavização é uma técnica aplicada a séries temporais para remover a variação refinada entre etapas de tempo. A expectativa da suavização é remover o ruído e expor melhor o sinal dos processos causais subjacentes. As médias móveis são um tipo simples e comum de suavização usado na análise de séries temporais e na previsão de séries temporais.

# %%
# Passos a frente: 1, 2 , 3 e 14 
# A seleção do 14 se deve ao fato na análise de autocorrelação, o lag 14, ter um leve destaque (bônus pra análise)

# %% [markdown]
# #### Passo 1

# %%
# Preparando os valores - PASSO 1
X = train['vitimas_total'].values
window = 1
history = [X[i] for i in range(window)]
testMM = test['vitimas_total'].values
modelo2 = list()

# "Andar" para a frente ao longo do tempo no teste
for t in range(len(testMM)):
    length = len(history)
    yhat = mean([history[i] for i in range(length-window,length)])
    obs = testMM[t]
    modelo2.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=6.000000, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=5.000000, expected=9.000000
# predicted=9.000000, expected=8.000000
# predicted=8.000000, expected=4.000000
# predicted=4.000000, expected=0.000000
# predicted=0.000000, expected=9.000000
# predicted=9.000000, expected=2.000000
# predicted=2.000000, expected=6.000000
# predicted=6.000000, expected=4.000000
# predicted=4.000000, expected=4.000000
# predicted=4.000000, expected=12.000000
# predicted=12.000000, expected=5.000000
# predicted=5.000000, expected=3.000000
# predicted=3.000000, expected=3.000000
# predicted=3.000000, expected=5.000000
# predicted=5.000000, expected=6.000000
# predicted=6.000000, expected=2.000000
# predicted=2.000000, expected=5.000000
# predicted=5.000000, expected=2.000000
# predicted=2.000000, expected=9.000000
# predicted=9.000000, expected=6.000000
# predicted=6.000000, expected=4.000000
# predicted=4.000000, expected=3.000000
# predicted=3.000000, expected=9.000000
# predicted=9.000000, expected=6.000000
# predicted=6.000000, expected=6.000000
# predicted=6.000000, expected=2.000000
# predicted=2.000000, expected=4.000000
# predicted=4.000000, expected=10.000000
# predicted=10.000000, expected=4.000000
# predicted=4.000000, expected=8.000000
# predicted=8.000000, expected=3.000000
# predicted=3.000000, expected=4.000000
# predicted=4.000000, expected=13.000000
# predicted=13.000000, expected=10.000000
# predicted=10.000000, expected=8.000000
# predicted=8.000000, expected=7.000000
# predicted=7.000000, expected=11.000000
# predicted=11.000000, expected=2.000000
# predicted=2.000000, expected=7.000000
# predicted=7.000000, expected=8.000000
# predicted=8.000000, expected=8.000000
# predicted=8.000000, expected=8.000000
# predicted=8.000000, expected=18.000000
# predicted=18.000000, expected=13.000000
# predicted=13.000000, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=5.000000, expected=1.000000
# predicted=1.000000, expected=4.000000
# predicted=4.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=7.000000, expected=5.000000
# predicted=5.000000, expected=5.000000
# predicted=5.000000, expected=1.000000
# predicted=1.000000, expected=15.000000
# predicted=15.000000, expected=5.000000
# predicted=5.000000, expected=8.000000
# predicted=8.000000, expected=3.000000
# predicted=3.000000, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=5.000000, expected=3.000000
# predicted=3.000000, expected=9.000000
# predicted=9.000000, expected=2.000000
# predicted=2.000000, expected=3.000000
# predicted=3.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=7.000000, expected=11.000000
# predicted=11.000000, expected=4.000000
# predicted=4.000000, expected=5.000000
# predicted=5.000000, expected=5.000000
# predicted=5.000000, expected=3.000000
# predicted=3.000000, expected=6.000000
# predicted=6.000000, expected=7.000000
# predicted=7.000000, expected=6.000000
# predicted=6.000000, expected=3.000000
# predicted=3.000000, expected=9.000000
# predicted=9.000000, expected=7.000000
# predicted=7.000000, expected=8.000000
# predicted=8.000000, expected=9.000000
# predicted=9.000000, expected=4.000000
# predicted=4.000000, expected=8.000000
# predicted=8.000000, expected=3.000000
# predicted=3.000000, expected=2.000000
# predicted=2.000000, expected=7.000000
# predicted=7.000000, expected=6.000000
# predicted=6.000000, expected=9.000000
# predicted=9.000000, expected=15.000000
# predicted=15.000000, expected=6.000000
# predicted=6.000000, expected=2.000000
# predicted=2.000000, expected=4.000000
# predicted=4.000000, expected=9.000000
# predicted=9.000000, expected=3.000000
# predicted=3.000000, expected=4.000000
# predicted=4.000000, expected=4.000000
# predicted=4.000000, expected=1.000000
# predicted=1.000000, expected=5.000000
# predicted=5.000000, expected=5.000000
# predicted=5.000000, expected=8.000000
# predicted=8.000000, expected=3.000000
# predicted=3.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=7.000000, expected=2.000000
# predicted=2.000000, expected=5.000000
# predicted=5.000000, expected=9.000000
# predicted=9.000000, expected=8.000000
# predicted=8.000000, expected=4.000000
# predicted=4.000000, expected=3.000000
# predicted=3.000000, expected=6.000000
# predicted=6.000000, expected=4.000000
# predicted=4.000000, expected=0.000000
# predicted=0.000000, expected=4.000000
# predicted=4.000000, expected=5.000000
# predicted=5.000000, expected=8.000000
# predicted=8.000000, expected=5.000000
# predicted=5.000000, expected=9.000000
# predicted=9.000000, expected=14.000000
# predicted=14.000000, expected=4.000000
# predicted=4.000000, expected=8.000000
# predicted=8.000000, expected=8.000000
# predicted=8.000000, expected=5.000000
# predicted=5.000000, expected=11.000000
# predicted=11.000000, expected=9.000000
# predicted=9.000000, expected=9.000000
# predicted=9.000000, expected=9.000000
# predicted=9.000000, expected=1.000000
# predicted=1.000000, expected=6.000000
# predicted=6.000000, expected=9.000000
# predicted=9.000000, expected=7.000000
# predicted=7.000000, expected=5.000000
# predicted=5.000000, expected=7.000000
# predicted=7.000000, expected=9.000000
# predicted=9.000000, expected=2.000000
# predicted=2.000000, expected=7.000000
# predicted=7.000000, expected=14.000000
# predicted=14.000000, expected=1.000000
# predicted=1.000000, expected=10.000000
# predicted=10.000000, expected=8.000000
# predicted=8.000000, expected=5.000000
# predicted=5.000000, expected=4.000000
# predicted=4.000000, expected=4.000000
# predicted=4.000000, expected=8.000000
# predicted=8.000000, expected=9.000000
# predicted=9.000000, expected=4.000000
# predicted=4.000000, expected=6.000000
# predicted=6.000000, expected=3.000000
# predicted=3.000000, expected=7.000000
# predicted=7.000000, expected=8.000000
# predicted=8.000000, expected=5.000000
# predicted=5.000000, expected=8.000000
# predicted=8.000000, expected=6.000000
# predicted=6.000000, expected=7.000000
# predicted=7.000000, expected=8.000000
# predicted=8.000000, expected=3.000000
# predicted=3.000000, expected=8.000000
# predicted=8.000000, expected=12.000000
# predicted=12.000000, expected=15.000000
# predicted=15.000000, expected=8.000000
# predicted=8.000000, expected=6.000000
# predicted=6.000000, expected=3.000000
# predicted=3.000000, expected=8.000000
# predicted=8.000000, expected=4.000000
# predicted=4.000000, expected=5.000000
# predicted=5.000000, expected=7.000000
# predicted=7.000000, expected=12.000000
# predicted=12.000000, expected=3.000000
# predicted=3.000000, expected=6.000000
# predicted=6.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=7.000000, expected=9.000000
# predicted=9.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=7.000000, expected=3.000000
# predicted=3.000000, expected=3.000000
# predicted=3.000000, expected=3.000000
# predicted=3.000000, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=5.000000, expected=6.000000
# predicted=6.000000, expected=11.000000
# predicted=11.000000, expected=2.000000
# predicted=2.000000, expected=4.000000
# predicted=4.000000, expected=16.000000
# predicted=16.000000, expected=9.000000
# predicted=9.000000, expected=12.000000
# predicted=12.000000, expected=5.000000
# predicted=5.000000, expected=7.000000
# predicted=7.000000, expected=3.000000
# predicted=3.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=7.000000, expected=2.000000
# predicted=2.000000, expected=7.000000
# predicted=7.000000, expected=8.000000
# predicted=8.000000, expected=1.000000
# predicted=1.000000, expected=9.000000
# predicted=9.000000, expected=3.000000
# predicted=3.000000, expected=4.000000
# predicted=4.000000, expected=4.000000
# predicted=4.000000, expected=14.000000
# predicted=14.000000, expected=10.000000
# predicted=10.000000, expected=5.000000
# predicted=5.000000, expected=4.000000
# predicted=4.000000, expected=8.000000
# predicted=8.000000, expected=6.000000
# predicted=6.000000, expected=9.000000
# predicted=9.000000, expected=3.000000
# predicted=3.000000, expected=7.000000
# predicted=7.000000, expected=6.000000
# predicted=6.000000, expected=3.000000
# predicted=3.000000, expected=6.000000
# predicted=6.000000, expected=5.000000
# predicted=5.000000, expected=6.000000
# predicted=6.000000, expected=4.000000
# predicted=4.000000, expected=5.000000
# predicted=5.000000, expected=11.000000
# predicted=11.000000, expected=1.000000
# predicted=1.000000, expected=9.000000
# predicted=9.000000, expected=7.000000
# predicted=7.000000, expected=5.000000
# predicted=5.000000, expected=9.000000
# predicted=9.000000, expected=10.000000
# predicted=10.000000, expected=7.000000
# predicted=7.000000, expected=9.000000
# predicted=9.000000, expected=4.000000
# predicted=4.000000, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=5.000000, expected=9.000000
# predicted=9.000000, expected=10.000000
# predicted=10.000000, expected=15.000000
# predicted=15.000000, expected=3.000000
# predicted=3.000000, expected=6.000000
# predicted=6.000000, expected=8.000000
# predicted=8.000000, expected=6.000000
# predicted=6.000000, expected=12.000000
# predicted=12.000000, expected=1.000000
# predicted=1.000000, expected=1.000000
# predicted=1.000000, expected=6.000000
# predicted=6.000000, expected=1.000000
# predicted=1.000000, expected=4.000000
# predicted=4.000000, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=5.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=7.000000, expected=3.000000
# predicted=3.000000, expected=4.000000
# predicted=4.000000, expected=4.000000
# predicted=4.000000, expected=5.000000
# predicted=5.000000, expected=6.000000
# predicted=6.000000, expected=8.000000
# predicted=8.000000, expected=12.000000
# predicted=12.000000, expected=5.000000
# predicted=5.000000, expected=5.000000
# predicted=5.000000, expected=4.000000
# predicted=4.000000, expected=9.000000
# predicted=9.000000, expected=10.000000
# predicted=10.000000, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=5.000000, expected=6.000000
# predicted=6.000000, expected=10.000000
# predicted=10.000000, expected=10.000000
# predicted=10.000000, expected=12.000000
# predicted=12.000000, expected=6.000000
# predicted=6.000000, expected=5.000000
# predicted=5.000000, expected=8.000000
# predicted=8.000000, expected=10.000000
# predicted=10.000000, expected=4.000000
# predicted=4.000000, expected=4.000000
# predicted=4.000000, expected=9.000000
# predicted=9.000000, expected=9.000000
# predicted=9.000000, expected=4.000000
# predicted=4.000000, expected=6.000000
# predicted=6.000000, expected=6.000000
# predicted=6.000000, expected=7.000000
# predicted=7.000000, expected=7.000000
# predicted=7.000000, expected=10.000000
# predicted=10.000000, expected=8.000000
# predicted=8.000000, expected=10.000000
# predicted=10.000000, expected=2.000000
# predicted=2.000000, expected=10.000000
# predicted=10.000000, expected=5.000000
# predicted=5.000000, expected=4.000000
# predicted=4.000000, expected=6.000000
# predicted=6.000000, expected=9.000000
# predicted=9.000000, expected=10.000000
# predicted=10.000000, expected=8.000000
# predicted=8.000000, expected=5.000000
# predicted=5.000000, expected=8.000000
# predicted=8.000000, expected=12.000000
# predicted=12.000000, expected=8.000000
# predicted=8.000000, expected=6.000000
# predicted=6.000000, expected=11.000000
# predicted=11.000000, expected=10.000000
# predicted=10.000000, expected=8.000000
# predicted=8.000000, expected=5.000000
# predicted=5.000000, expected=7.000000
# predicted=7.000000, expected=4.000000
# predicted=4.000000, expected=5.000000
# predicted=5.000000, expected=8.000000
# predicted=8.000000, expected=3.000000
# predicted=3.000000, expected=4.000000
# predicted=4.000000, expected=8.000000
# predicted=8.000000, expected=10.000000
# predicted=10.000000, expected=8.000000
# predicted=8.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=7.000000, expected=10.000000
# predicted=10.000000, expected=4.000000
# predicted=4.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=7.000000, expected=7.000000
# predicted=7.000000, expected=11.000000
# predicted=11.000000, expected=12.000000
# predicted=12.000000, expected=13.000000
# predicted=13.000000, expected=6.000000
# predicted=6.000000, expected=8.000000
# predicted=8.000000, expected=5.000000
# predicted=5.000000, expected=5.000000
# predicted=5.000000, expected=20.000000
# predicted=20.000000, expected=4.000000
# predicted=4.000000, expected=6.000000
# predicted=6.000000, expected=2.000000
# predicted=2.000000, expected=4.000000
# predicted=4.000000, expected=6.000000
# predicted=6.000000, expected=7.000000
# predicted=7.000000, expected=9.000000
# predicted=9.000000, expected=6.000000
# predicted=6.000000, expected=17.000000
# predicted=17.000000, expected=2.000000
# predicted=2.000000, expected=11.000000
# predicted=11.000000, expected=6.000000
# predicted=6.000000, expected=6.000000
# predicted=6.000000, expected=6.000000
# predicted=6.000000, expected=7.000000
# predicted=7.000000, expected=11.000000
# predicted=11.000000, expected=8.000000
# predicted=8.000000, expected=7.000000
# predicted=7.000000, expected=12.000000
# predicted=12.000000, expected=18.000000
# predicted=18.000000, expected=6.000000
# predicted=6.000000, expected=4.000000
# predicted=4.000000, expected=14.000000
# predicted=14.000000, expected=8.000000
# predicted=8.000000, expected=8.000000
# predicted=8.000000, expected=10.000000
# predicted=10.000000, expected=10.000000
# predicted=10.000000, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=5.000000, expected=10.000000
# predicted=10.000000, expected=9.000000
# predicted=9.000000, expected=3.000000
# predicted=3.000000, expected=18.000000
# predicted=18.000000, expected=11.000000
# predicted=11.000000, expected=7.000000
# predicted=7.000000, expected=8.000000
# predicted=8.000000, expected=11.000000
# predicted=11.000000, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=5.000000, expected=12.000000
# predicted=12.000000, expected=7.000000
# predicted=7.000000, expected=8.000000
# predicted=8.000000, expected=8.000000
# predicted=8.000000, expected=7.000000
# predicted=7.000000, expected=5.000000
# predicted=5.000000, expected=4.000000
# predicted=4.000000, expected=5.000000
# predicted=5.000000, expected=2.000000

# %%
# Métricas para mensurar o modelo
print('Erro médio absoluto (MSE):',
      round(mean_absolute_error(testMM, modelo2), 3))
print('Raiz do erro médio quadrado (RMSE):',
      round(mean_squared_error(testMM, modelo2)**0.5, 3))
print('Soma quadratica dos erros (SSE):',
      round(np.sum((modelo2 - testMM)**2), 3))
print('Erro medio percentual absoluto (MAPE):',
      np.mean(np.abs((testMM - modelo2)/testMM))*100)
# Out:
# Erro médio absoluto (MSE): 3.551
# Raiz do erro médio quadrado (RMSE): 4.579
# Soma quadratica dos erros (SSE): 7652.0
# Erro medio percentual absoluto (MAPE): inf

# %%
plt.plot(testMM, color = 'blue', label = 'Real')
plt.plot(modelo2, color = 'red', label = 'Previsto')
plt.title('Modelo 2 - Suavização de Media Móvel (1 passo a frente)')
plt.xlabel('Tempo')
plt.ylabel('Vitimas de acidentes')
plt.legend()
plt.show()

# %% [markdown]
# #### Passo 2

# %%
# Preparando os valores - PASSO 2
X = train['vitimas_total'].values
window = 2
history = [X[i] for i in range(window)]
testMM = test['vitimas_total'].values
modelo2 = list()

# "Andar" para a frente ao longo do tempo no teste
for t in range(len(testMM)):
    length = len(history)
    yhat = mean([history[i] for i in range(length-window,length)])
    obs = testMM[t]
    modelo2.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=7.000000, expected=9.000000
# predicted=8.500000, expected=5.000000
# predicted=7.000000, expected=9.000000
# predicted=7.000000, expected=8.000000
# predicted=8.500000, expected=4.000000
# predicted=6.000000, expected=0.000000
# predicted=2.000000, expected=9.000000
# predicted=4.500000, expected=2.000000
# predicted=5.500000, expected=6.000000
# predicted=4.000000, expected=4.000000
# predicted=5.000000, expected=4.000000
# predicted=4.000000, expected=12.000000
# predicted=8.000000, expected=5.000000
# predicted=8.500000, expected=3.000000
# predicted=4.000000, expected=3.000000
# predicted=3.000000, expected=5.000000
# predicted=4.000000, expected=6.000000
# predicted=5.500000, expected=2.000000
# predicted=4.000000, expected=5.000000
# predicted=3.500000, expected=2.000000
# predicted=3.500000, expected=9.000000
# predicted=5.500000, expected=6.000000
# predicted=7.500000, expected=4.000000
# predicted=5.000000, expected=3.000000
# predicted=3.500000, expected=9.000000
# predicted=6.000000, expected=6.000000
# predicted=7.500000, expected=6.000000
# predicted=6.000000, expected=2.000000
# predicted=4.000000, expected=4.000000
# predicted=3.000000, expected=10.000000
# predicted=7.000000, expected=4.000000
# predicted=7.000000, expected=8.000000
# predicted=6.000000, expected=3.000000
# predicted=5.500000, expected=4.000000
# predicted=3.500000, expected=13.000000
# predicted=8.500000, expected=10.000000
# predicted=11.500000, expected=8.000000
# predicted=9.000000, expected=7.000000
# predicted=7.500000, expected=11.000000
# predicted=9.000000, expected=2.000000
# predicted=6.500000, expected=7.000000
# predicted=4.500000, expected=8.000000
# predicted=7.500000, expected=8.000000
# predicted=8.000000, expected=8.000000
# predicted=8.000000, expected=18.000000
# predicted=13.000000, expected=13.000000
# predicted=15.500000, expected=9.000000
# predicted=11.000000, expected=5.000000
# predicted=7.000000, expected=1.000000
# predicted=3.000000, expected=4.000000
# predicted=2.500000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=5.500000, expected=5.000000
# predicted=6.000000, expected=5.000000
# predicted=5.000000, expected=1.000000
# predicted=3.000000, expected=15.000000
# predicted=8.000000, expected=5.000000
# predicted=10.000000, expected=8.000000
# predicted=6.500000, expected=3.000000
# predicted=5.500000, expected=9.000000
# predicted=6.000000, expected=5.000000
# predicted=7.000000, expected=3.000000
# predicted=4.000000, expected=9.000000
# predicted=6.000000, expected=2.000000
# predicted=5.500000, expected=3.000000
# predicted=2.500000, expected=4.000000
# predicted=3.500000, expected=7.000000
# predicted=5.500000, expected=11.000000
# predicted=9.000000, expected=4.000000
# predicted=7.500000, expected=5.000000
# predicted=4.500000, expected=5.000000
# predicted=5.000000, expected=3.000000
# predicted=4.000000, expected=6.000000
# predicted=4.500000, expected=7.000000
# predicted=6.500000, expected=6.000000
# predicted=6.500000, expected=3.000000
# predicted=4.500000, expected=9.000000
# predicted=6.000000, expected=7.000000
# predicted=8.000000, expected=8.000000
# predicted=7.500000, expected=9.000000
# predicted=8.500000, expected=4.000000
# predicted=6.500000, expected=8.000000
# predicted=6.000000, expected=3.000000
# predicted=5.500000, expected=2.000000
# predicted=2.500000, expected=7.000000
# predicted=4.500000, expected=6.000000
# predicted=6.500000, expected=9.000000
# predicted=7.500000, expected=15.000000
# predicted=12.000000, expected=6.000000
# predicted=10.500000, expected=2.000000
# predicted=4.000000, expected=4.000000
# predicted=3.000000, expected=9.000000
# predicted=6.500000, expected=3.000000
# predicted=6.000000, expected=4.000000
# predicted=3.500000, expected=4.000000
# predicted=4.000000, expected=1.000000
# predicted=2.500000, expected=5.000000
# predicted=3.000000, expected=5.000000
# predicted=5.000000, expected=8.000000
# predicted=6.500000, expected=3.000000
# predicted=5.500000, expected=4.000000
# predicted=3.500000, expected=7.000000
# predicted=5.500000, expected=2.000000
# predicted=4.500000, expected=5.000000
# predicted=3.500000, expected=9.000000
# predicted=7.000000, expected=8.000000
# predicted=8.500000, expected=4.000000
# predicted=6.000000, expected=3.000000
# predicted=3.500000, expected=6.000000
# predicted=4.500000, expected=4.000000
# predicted=5.000000, expected=0.000000
# predicted=2.000000, expected=4.000000
# predicted=2.000000, expected=5.000000
# predicted=4.500000, expected=8.000000
# predicted=6.500000, expected=5.000000
# predicted=6.500000, expected=9.000000
# predicted=7.000000, expected=14.000000
# predicted=11.500000, expected=4.000000
# predicted=9.000000, expected=8.000000
# predicted=6.000000, expected=8.000000
# predicted=8.000000, expected=5.000000
# predicted=6.500000, expected=11.000000
# predicted=8.000000, expected=9.000000
# predicted=10.000000, expected=9.000000
# predicted=9.000000, expected=9.000000
# predicted=9.000000, expected=1.000000
# predicted=5.000000, expected=6.000000
# predicted=3.500000, expected=9.000000
# predicted=7.500000, expected=7.000000
# predicted=8.000000, expected=5.000000
# predicted=6.000000, expected=7.000000
# predicted=6.000000, expected=9.000000
# predicted=8.000000, expected=2.000000
# predicted=5.500000, expected=7.000000
# predicted=4.500000, expected=14.000000
# predicted=10.500000, expected=1.000000
# predicted=7.500000, expected=10.000000
# predicted=5.500000, expected=8.000000
# predicted=9.000000, expected=5.000000
# predicted=6.500000, expected=4.000000
# predicted=4.500000, expected=4.000000
# predicted=4.000000, expected=8.000000
# predicted=6.000000, expected=9.000000
# predicted=8.500000, expected=4.000000
# predicted=6.500000, expected=6.000000
# predicted=5.000000, expected=3.000000
# predicted=4.500000, expected=7.000000
# predicted=5.000000, expected=8.000000
# predicted=7.500000, expected=5.000000
# predicted=6.500000, expected=8.000000
# predicted=6.500000, expected=6.000000
# predicted=7.000000, expected=7.000000
# predicted=6.500000, expected=8.000000
# predicted=7.500000, expected=3.000000
# predicted=5.500000, expected=8.000000
# predicted=5.500000, expected=12.000000
# predicted=10.000000, expected=15.000000
# predicted=13.500000, expected=8.000000
# predicted=11.500000, expected=6.000000
# predicted=7.000000, expected=3.000000
# predicted=4.500000, expected=8.000000
# predicted=5.500000, expected=4.000000
# predicted=6.000000, expected=5.000000
# predicted=4.500000, expected=7.000000
# predicted=6.000000, expected=12.000000
# predicted=9.500000, expected=3.000000
# predicted=7.500000, expected=6.000000
# predicted=4.500000, expected=4.000000
# predicted=5.000000, expected=7.000000
# predicted=5.500000, expected=9.000000
# predicted=8.000000, expected=4.000000
# predicted=6.500000, expected=7.000000
# predicted=5.500000, expected=3.000000
# predicted=5.000000, expected=3.000000
# predicted=3.000000, expected=3.000000
# predicted=3.000000, expected=9.000000
# predicted=6.000000, expected=5.000000
# predicted=7.000000, expected=6.000000
# predicted=5.500000, expected=11.000000
# predicted=8.500000, expected=2.000000
# predicted=6.500000, expected=4.000000
# predicted=3.000000, expected=16.000000
# predicted=10.000000, expected=9.000000
# predicted=12.500000, expected=12.000000
# predicted=10.500000, expected=5.000000
# predicted=8.500000, expected=7.000000
# predicted=6.000000, expected=3.000000
# predicted=5.000000, expected=4.000000
# predicted=3.500000, expected=7.000000
# predicted=5.500000, expected=2.000000
# predicted=4.500000, expected=7.000000
# predicted=4.500000, expected=8.000000
# predicted=7.500000, expected=1.000000
# predicted=4.500000, expected=9.000000
# predicted=5.000000, expected=3.000000
# predicted=6.000000, expected=4.000000
# predicted=3.500000, expected=4.000000
# predicted=4.000000, expected=14.000000
# predicted=9.000000, expected=10.000000
# predicted=12.000000, expected=5.000000
# predicted=7.500000, expected=4.000000
# predicted=4.500000, expected=8.000000
# predicted=6.000000, expected=6.000000
# predicted=7.000000, expected=9.000000
# predicted=7.500000, expected=3.000000
# predicted=6.000000, expected=7.000000
# predicted=5.000000, expected=6.000000
# predicted=6.500000, expected=3.000000
# predicted=4.500000, expected=6.000000
# predicted=4.500000, expected=5.000000
# predicted=5.500000, expected=6.000000
# predicted=5.500000, expected=4.000000
# predicted=5.000000, expected=5.000000
# predicted=4.500000, expected=11.000000
# predicted=8.000000, expected=1.000000
# predicted=6.000000, expected=9.000000
# predicted=5.000000, expected=7.000000
# predicted=8.000000, expected=5.000000
# predicted=6.000000, expected=9.000000
# predicted=7.000000, expected=10.000000
# predicted=9.500000, expected=7.000000
# predicted=8.500000, expected=9.000000
# predicted=8.000000, expected=4.000000
# predicted=6.500000, expected=9.000000
# predicted=6.500000, expected=5.000000
# predicted=7.000000, expected=9.000000
# predicted=7.000000, expected=10.000000
# predicted=9.500000, expected=15.000000
# predicted=12.500000, expected=3.000000
# predicted=9.000000, expected=6.000000
# predicted=4.500000, expected=8.000000
# predicted=7.000000, expected=6.000000
# predicted=7.000000, expected=12.000000
# predicted=9.000000, expected=1.000000
# predicted=6.500000, expected=1.000000
# predicted=1.000000, expected=6.000000
# predicted=3.500000, expected=1.000000
# predicted=3.500000, expected=4.000000
# predicted=2.500000, expected=9.000000
# predicted=6.500000, expected=5.000000
# predicted=7.000000, expected=4.000000
# predicted=4.500000, expected=7.000000
# predicted=5.500000, expected=3.000000
# predicted=5.000000, expected=4.000000
# predicted=3.500000, expected=4.000000
# predicted=4.000000, expected=5.000000
# predicted=4.500000, expected=6.000000
# predicted=5.500000, expected=8.000000
# predicted=7.000000, expected=12.000000
# predicted=10.000000, expected=5.000000
# predicted=8.500000, expected=5.000000
# predicted=5.000000, expected=4.000000
# predicted=4.500000, expected=9.000000
# predicted=6.500000, expected=10.000000
# predicted=9.500000, expected=9.000000
# predicted=9.500000, expected=5.000000
# predicted=7.000000, expected=6.000000
# predicted=5.500000, expected=10.000000
# predicted=8.000000, expected=10.000000
# predicted=10.000000, expected=12.000000
# predicted=11.000000, expected=6.000000
# predicted=9.000000, expected=5.000000
# predicted=5.500000, expected=8.000000
# predicted=6.500000, expected=10.000000
# predicted=9.000000, expected=4.000000
# predicted=7.000000, expected=4.000000
# predicted=4.000000, expected=9.000000
# predicted=6.500000, expected=9.000000
# predicted=9.000000, expected=4.000000
# predicted=6.500000, expected=6.000000
# predicted=5.000000, expected=6.000000
# predicted=6.000000, expected=7.000000
# predicted=6.500000, expected=7.000000
# predicted=7.000000, expected=10.000000
# predicted=8.500000, expected=8.000000
# predicted=9.000000, expected=10.000000
# predicted=9.000000, expected=2.000000
# predicted=6.000000, expected=10.000000
# predicted=6.000000, expected=5.000000
# predicted=7.500000, expected=4.000000
# predicted=4.500000, expected=6.000000
# predicted=5.000000, expected=9.000000
# predicted=7.500000, expected=10.000000
# predicted=9.500000, expected=8.000000
# predicted=9.000000, expected=5.000000
# predicted=6.500000, expected=8.000000
# predicted=6.500000, expected=12.000000
# predicted=10.000000, expected=8.000000
# predicted=10.000000, expected=6.000000
# predicted=7.000000, expected=11.000000
# predicted=8.500000, expected=10.000000
# predicted=10.500000, expected=8.000000
# predicted=9.000000, expected=5.000000
# predicted=6.500000, expected=7.000000
# predicted=6.000000, expected=4.000000
# predicted=5.500000, expected=5.000000
# predicted=4.500000, expected=8.000000
# predicted=6.500000, expected=3.000000
# predicted=5.500000, expected=4.000000
# predicted=3.500000, expected=8.000000
# predicted=6.000000, expected=10.000000
# predicted=9.000000, expected=8.000000
# predicted=9.000000, expected=4.000000
# predicted=6.000000, expected=7.000000
# predicted=5.500000, expected=10.000000
# predicted=8.500000, expected=4.000000
# predicted=7.000000, expected=4.000000
# predicted=4.000000, expected=7.000000
# predicted=5.500000, expected=7.000000
# predicted=7.000000, expected=11.000000
# predicted=9.000000, expected=12.000000
# predicted=11.500000, expected=13.000000
# predicted=12.500000, expected=6.000000
# predicted=9.500000, expected=8.000000
# predicted=7.000000, expected=5.000000
# predicted=6.500000, expected=5.000000
# predicted=5.000000, expected=20.000000
# predicted=12.500000, expected=4.000000
# predicted=12.000000, expected=6.000000
# predicted=5.000000, expected=2.000000
# predicted=4.000000, expected=4.000000
# predicted=3.000000, expected=6.000000
# predicted=5.000000, expected=7.000000
# predicted=6.500000, expected=9.000000
# predicted=8.000000, expected=6.000000
# predicted=7.500000, expected=17.000000
# predicted=11.500000, expected=2.000000
# predicted=9.500000, expected=11.000000
# predicted=6.500000, expected=6.000000
# predicted=8.500000, expected=6.000000
# predicted=6.000000, expected=6.000000
# predicted=6.000000, expected=7.000000
# predicted=6.500000, expected=11.000000
# predicted=9.000000, expected=8.000000
# predicted=9.500000, expected=7.000000
# predicted=7.500000, expected=12.000000
# predicted=9.500000, expected=18.000000
# predicted=15.000000, expected=6.000000
# predicted=12.000000, expected=4.000000
# predicted=5.000000, expected=14.000000
# predicted=9.000000, expected=8.000000
# predicted=11.000000, expected=8.000000
# predicted=8.000000, expected=10.000000
# predicted=9.000000, expected=10.000000
# predicted=10.000000, expected=9.000000
# predicted=9.500000, expected=5.000000
# predicted=7.000000, expected=10.000000
# predicted=7.500000, expected=9.000000
# predicted=9.500000, expected=3.000000
# predicted=6.000000, expected=18.000000
# predicted=10.500000, expected=11.000000
# predicted=14.500000, expected=7.000000
# predicted=9.000000, expected=8.000000
# predicted=7.500000, expected=11.000000
# predicted=9.500000, expected=9.000000
# predicted=10.000000, expected=5.000000
# predicted=7.000000, expected=12.000000
# predicted=8.500000, expected=7.000000
# predicted=9.500000, expected=8.000000
# predicted=7.500000, expected=8.000000
# predicted=8.000000, expected=7.000000
# predicted=7.500000, expected=5.000000
# predicted=6.000000, expected=4.000000
# predicted=4.500000, expected=5.000000
# predicted=4.500000, expected=2.000000

# %%
# Métricas para mensurar o modelo
print('Erro médio absoluto (MSE):',
      round(mean_absolute_error(testMM, modelo2), 3))
print('Raiz do erro médio quadrado (RMSE):',
      round(mean_squared_error(testMM, modelo2)**0.5, 3))
print('Soma quadratica dos erros (SSE):',
      round(np.sum((modelo2 - testMM)**2), 3))
print('Erro medio percentual absoluto (MAPE):',
      np.mean(np.abs((testMM - modelo2)/testMM))*100)
# Out:
# Erro médio absoluto (MSE): 3.16
# Raiz do erro médio quadrado (RMSE): 4.003
# Soma quadratica dos erros (SSE): 5849.75
# Erro medio percentual absoluto (MAPE): inf

# %%
plt.plot(testMM, color = 'blue', label = 'Real')
plt.plot(modelo2, color = 'red', label = 'Previsto')
plt.title('Modelo 2 - Suavização de Media Móvel (2 passos a frente)')
plt.xlabel('Tempo')
plt.ylabel('Vitimas de acidentes')
plt.legend()
plt.show()

# %% [markdown]
# #### Passo 3

# %%
# Preparando os valores - PASSO 3
X = train['vitimas_total'].values
window = 3
history = [X[i] for i in range(window)]
testMM = test['vitimas_total'].values
modelo2 = list()

# "Andar" para a frente ao longo do tempo no teste
for t in range(len(testMM)):
    length = len(history)
    yhat = mean([history[i] for i in range(length-window,length)])
    obs = testMM[t]
    modelo2.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# predicted=12.000000, expected=8.000000
# predicted=8.666667, expected=11.000000
# predicted=8.666667, expected=9.000000
# predicted=9.333333, expected=5.000000
# predicted=8.333333, expected=12.000000
# predicted=8.666667, expected=7.000000
# predicted=8.000000, expected=8.000000
# predicted=9.000000, expected=8.000000
# predicted=7.666667, expected=7.000000
# predicted=7.666667, expected=5.000000
# predicted=6.666667, expected=4.000000
# predicted=5.333333, expected=5.000000
# predicted=4.666667, expected=2.000000

# %%
# Métricas para mensurar o modelo
print('Erro médio absoluto (MSE):',
      round(mean_absolute_error(testMM, modelo2), 3))
print('Raiz do erro médio quadrado (RMSE):',
      round(mean_squared_error(testMM, modelo2)**0.5, 3))
print('Soma quadratica dos erros (SSE):',
      round(np.sum((modelo2 - testMM)**2), 3))
print('Erro medio percentual absoluto (MAPE):',
      np.mean(np.abs((testMM - modelo2)/testMM))*100)
# Out:
# Erro médio absoluto (MSE): 2.933
# Raiz do erro médio quadrado (RMSE): 3.73
# Soma quadratica dos erros (SSE): 5078.889
# Erro medio percentual absoluto (MAPE): inf

# %%
plt.plot(testMM, color = 'blue', label = 'Real')
plt.plot(modelo2, color = 'red', label = 'Previsto')
plt.title('Modelo 2 - Suavização de Media Móvel (3 passos a frente)')
plt.xlabel('Tempo')
plt.ylabel('Vitimas de acidentes')
plt.legend()
plt.show()

# %% [markdown]
# #### Passo 14

# %%
# Preparando os valores - PASSO 14
X = train['vitimas_total'].values
window = 14
history = [X[i] for i in range(window)]
testMM = test['vitimas_total'].values
modelo2 = list()

# "Andar" para a frente ao longo do tempo no teste
for t in range(len(testMM)):
    length = len(history)
    yhat = mean([history[i] for i in range(length-window,length)])
    obs = testMM[t]
    modelo2.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=7.214286, expected=9.000000
# predicted=7.428571, expected=5.000000
# predicted=7.214286, expected=9.000000
# predicted=7.571429, expected=8.000000
# predicted=7.857143, expected=4.000000
# predicted=7.571429, expected=0.000000
# predicted=6.571429, expected=9.000000
# predicted=6.857143, expected=2.000000
# predicted=6.285714, expected=6.000000
# predicted=5.857143, expected=4.000000
# predicted=5.928571, expected=4.000000
# predicted=5.428571, expected=12.000000
# predicted=5.714286, expected=5.000000
# predicted=5.642857, expected=3.000000
# predicted=5.714286, expected=3.000000
# predicted=5.285714, expected=5.000000
# predicted=5.285714, expected=6.000000
# predicted=5.071429, expected=2.000000
# predicted=4.642857, expected=5.000000
# predicted=4.714286, expected=2.000000
# predicted=4.857143, expected=9.000000
# predicted=4.857143, expected=6.000000
# predicted=5.142857, expected=4.000000
# predicted=5.000000, expected=3.000000
# predicted=4.928571, expected=9.000000
# predicted=5.285714, expected=6.000000
# predicted=4.857143, expected=6.000000
# predicted=4.928571, expected=2.000000
# predicted=4.857143, expected=4.000000
# predicted=4.928571, expected=10.000000
# predicted=5.285714, expected=4.000000
# predicted=5.142857, expected=8.000000
# predicted=5.571429, expected=3.000000
# predicted=5.428571, expected=4.000000
# predicted=5.571429, expected=13.000000
# predicted=5.857143, expected=10.000000
# predicted=6.142857, expected=8.000000
# predicted=6.428571, expected=7.000000
# predicted=6.714286, expected=11.000000
# predicted=6.857143, expected=2.000000
# predicted=6.571429, expected=7.000000
# predicted=6.642857, expected=8.000000
# predicted=7.071429, expected=8.000000
# predicted=7.357143, expected=8.000000
# predicted=7.214286, expected=18.000000
# predicted=8.214286, expected=13.000000
# predicted=8.571429, expected=9.000000
# predicted=9.000000, expected=5.000000
# predicted=9.071429, expected=1.000000
# predicted=8.214286, expected=4.000000
# predicted=7.785714, expected=4.000000
# predicted=7.500000, expected=7.000000
# predicted=7.500000, expected=5.000000
# predicted=7.071429, expected=5.000000
# predicted=7.285714, expected=1.000000
# predicted=6.857143, expected=15.000000
# predicted=7.357143, expected=5.000000
# predicted=7.142857, expected=8.000000
# predicted=7.142857, expected=3.000000
# predicted=6.071429, expected=9.000000
# predicted=5.785714, expected=5.000000
# predicted=5.500000, expected=3.000000
# predicted=5.357143, expected=9.000000
# predicted=5.928571, expected=2.000000
# predicted=5.785714, expected=3.000000
# predicted=5.714286, expected=4.000000
# predicted=5.500000, expected=7.000000
# predicted=5.642857, expected=11.000000
# predicted=6.071429, expected=4.000000
# predicted=6.285714, expected=5.000000
# predicted=5.571429, expected=5.000000
# predicted=5.571429, expected=3.000000
# predicted=5.214286, expected=6.000000
# predicted=5.428571, expected=7.000000
# predicted=5.285714, expected=6.000000
# predicted=5.357143, expected=3.000000
# predicted=5.357143, expected=9.000000
# predicted=5.357143, expected=7.000000
# predicted=5.714286, expected=8.000000
# predicted=6.071429, expected=9.000000
# predicted=6.428571, expected=4.000000
# predicted=6.214286, expected=8.000000
# predicted=6.000000, expected=3.000000
# predicted=5.928571, expected=2.000000
# predicted=5.714286, expected=7.000000
# predicted=5.857143, expected=6.000000
# predicted=6.071429, expected=9.000000
# predicted=6.285714, expected=15.000000
# predicted=6.857143, expected=6.000000
# predicted=6.857143, expected=2.000000
# predicted=6.785714, expected=4.000000
# predicted=6.428571, expected=9.000000
# predicted=6.571429, expected=3.000000
# predicted=6.214286, expected=4.000000
# predicted=5.857143, expected=4.000000
# predicted=5.857143, expected=1.000000
# predicted=5.357143, expected=5.000000
# predicted=5.500000, expected=5.000000
# predicted=5.714286, expected=8.000000
# predicted=5.785714, expected=3.000000
# predicted=5.571429, expected=4.000000
# predicted=5.214286, expected=7.000000
# predicted=4.642857, expected=2.000000
# predicted=4.357143, expected=5.000000
# predicted=4.571429, expected=9.000000
# predicted=4.928571, expected=8.000000
# predicted=4.857143, expected=4.000000
# predicted=4.928571, expected=3.000000
# predicted=4.857143, expected=6.000000
# predicted=5.000000, expected=4.000000
# predicted=5.214286, expected=0.000000
# predicted=4.857143, expected=4.000000
# predicted=4.785714, expected=5.000000
# predicted=4.571429, expected=8.000000
# predicted=4.928571, expected=5.000000
# predicted=5.000000, expected=9.000000
# predicted=5.142857, expected=14.000000
# predicted=6.000000, expected=4.000000
# predicted=5.928571, expected=8.000000
# predicted=5.857143, expected=8.000000
# predicted=5.857143, expected=5.000000
# predicted=5.928571, expected=11.000000
# predicted=6.500000, expected=9.000000
# predicted=6.714286, expected=9.000000
# predicted=7.071429, expected=9.000000
# predicted=7.714286, expected=1.000000
# predicted=7.500000, expected=6.000000
# predicted=7.571429, expected=9.000000
# predicted=7.642857, expected=7.000000
# predicted=7.785714, expected=5.000000
# predicted=7.500000, expected=7.000000
# predicted=7.000000, expected=9.000000
# predicted=7.357143, expected=2.000000
# predicted=6.928571, expected=7.000000
# predicted=6.857143, expected=14.000000
# predicted=7.500000, expected=1.000000
# predicted=6.785714, expected=10.000000
# predicted=6.857143, expected=8.000000
# predicted=6.785714, expected=5.000000
# predicted=6.500000, expected=4.000000
# predicted=6.714286, expected=4.000000
# predicted=6.571429, expected=8.000000
# predicted=6.500000, expected=9.000000
# predicted=6.642857, expected=4.000000
# predicted=6.571429, expected=6.000000
# predicted=6.500000, expected=3.000000
# predicted=6.071429, expected=7.000000
# predicted=6.428571, expected=8.000000
# predicted=6.500000, expected=5.000000
# predicted=5.857143, expected=8.000000
# predicted=6.357143, expected=6.000000
# predicted=6.071429, expected=7.000000
# predicted=6.000000, expected=8.000000
# predicted=6.214286, expected=3.000000
# predicted=6.142857, expected=8.000000
# predicted=6.428571, expected=12.000000
# predicted=6.714286, expected=15.000000
# predicted=7.142857, expected=8.000000
# predicted=7.428571, expected=6.000000
# predicted=7.428571, expected=3.000000
# predicted=7.428571, expected=8.000000
# predicted=7.500000, expected=4.000000
# predicted=7.214286, expected=5.000000
# predicted=7.214286, expected=7.000000
# predicted=7.142857, expected=12.000000
# predicted=7.571429, expected=3.000000
# predicted=7.285714, expected=6.000000
# predicted=7.142857, expected=4.000000
# predicted=7.214286, expected=7.000000
# predicted=7.142857, expected=9.000000
# predicted=6.928571, expected=4.000000
# predicted=6.142857, expected=7.000000
# predicted=6.071429, expected=3.000000
# predicted=5.857143, expected=3.000000
# predicted=5.857143, expected=3.000000
# predicted=5.500000, expected=9.000000
# predicted=5.857143, expected=5.000000
# predicted=5.857143, expected=6.000000
# predicted=5.785714, expected=11.000000
# predicted=5.714286, expected=2.000000
# predicted=5.642857, expected=4.000000
# predicted=5.500000, expected=16.000000
# predicted=6.357143, expected=9.000000
# predicted=6.500000, expected=12.000000
# predicted=6.714286, expected=5.000000
# predicted=6.785714, expected=7.000000
# predicted=6.785714, expected=3.000000
# predicted=6.785714, expected=4.000000
# predicted=6.857143, expected=7.000000
# predicted=7.142857, expected=2.000000
# predicted=6.642857, expected=7.000000
# predicted=6.785714, expected=8.000000
# predicted=6.928571, expected=1.000000
# predicted=6.214286, expected=9.000000
# predicted=6.714286, expected=3.000000
# predicted=6.642857, expected=4.000000
# predicted=5.785714, expected=4.000000
# predicted=5.428571, expected=14.000000
# predicted=5.571429, expected=10.000000
# predicted=5.928571, expected=5.000000
# predicted=5.785714, expected=4.000000
# predicted=5.857143, expected=8.000000
# predicted=6.142857, expected=6.000000
# predicted=6.071429, expected=9.000000
# predicted=6.571429, expected=3.000000
# predicted=6.285714, expected=7.000000
# predicted=6.214286, expected=6.000000
# predicted=6.571429, expected=3.000000
# predicted=6.142857, expected=6.000000
# predicted=6.357143, expected=5.000000
# predicted=6.428571, expected=6.000000
# predicted=6.571429, expected=4.000000
# predicted=5.857143, expected=5.000000
# predicted=5.500000, expected=11.000000
# predicted=5.928571, expected=1.000000
# predicted=5.714286, expected=9.000000
# predicted=5.785714, expected=7.000000
# predicted=5.857143, expected=5.000000
# predicted=5.571429, expected=9.000000
# predicted=6.000000, expected=10.000000
# predicted=6.214286, expected=7.000000
# predicted=6.285714, expected=9.000000
# predicted=6.714286, expected=4.000000
# predicted=6.571429, expected=9.000000
# predicted=6.857143, expected=5.000000
# predicted=6.785714, expected=9.000000
# predicted=7.142857, expected=10.000000
# predicted=7.500000, expected=15.000000
# predicted=7.785714, expected=3.000000
# predicted=7.928571, expected=6.000000
# predicted=7.714286, expected=8.000000
# predicted=7.785714, expected=6.000000
# predicted=7.857143, expected=12.000000
# predicted=8.071429, expected=1.000000
# predicted=7.428571, expected=1.000000
# predicted=7.000000, expected=6.000000
# predicted=6.785714, expected=1.000000
# predicted=6.571429, expected=4.000000
# predicted=6.214286, expected=9.000000
# predicted=6.500000, expected=5.000000
# predicted=6.214286, expected=4.000000
# predicted=5.785714, expected=7.000000
# predicted=5.214286, expected=3.000000
# predicted=5.214286, expected=4.000000
# predicted=5.071429, expected=4.000000
# predicted=4.785714, expected=5.000000
# predicted=4.714286, expected=6.000000
# predicted=4.285714, expected=8.000000
# predicted=4.785714, expected=12.000000
# predicted=5.571429, expected=5.000000
# predicted=5.500000, expected=5.000000
# predicted=5.785714, expected=4.000000
# predicted=5.785714, expected=9.000000
# predicted=5.785714, expected=10.000000
# predicted=6.142857, expected=9.000000
# predicted=6.500000, expected=5.000000
# predicted=6.357143, expected=6.000000
# predicted=6.571429, expected=10.000000
# predicted=7.000000, expected=10.000000
# predicted=7.428571, expected=12.000000
# predicted=7.928571, expected=6.000000
# predicted=7.928571, expected=5.000000
# predicted=7.714286, expected=8.000000
# predicted=7.428571, expected=10.000000
# predicted=7.785714, expected=4.000000
# predicted=7.714286, expected=4.000000
# predicted=7.714286, expected=9.000000
# predicted=7.714286, expected=9.000000
# predicted=7.642857, expected=4.000000
# predicted=7.285714, expected=6.000000
# predicted=7.357143, expected=6.000000
# predicted=7.357143, expected=7.000000
# predicted=7.142857, expected=7.000000
# predicted=6.928571, expected=10.000000
# predicted=6.785714, expected=8.000000
# predicted=6.928571, expected=10.000000
# predicted=7.285714, expected=2.000000
# predicted=6.857143, expected=10.000000
# predicted=6.857143, expected=5.000000
# predicted=6.928571, expected=4.000000
# predicted=6.928571, expected=6.000000
# predicted=6.714286, expected=9.000000
# predicted=6.714286, expected=10.000000
# predicted=7.142857, expected=8.000000
# predicted=7.285714, expected=5.000000
# predicted=7.214286, expected=8.000000
# predicted=7.285714, expected=12.000000
# predicted=7.642857, expected=8.000000
# predicted=7.500000, expected=6.000000
# predicted=7.357143, expected=11.000000
# predicted=7.428571, expected=10.000000
# predicted=8.000000, expected=8.000000
# predicted=7.857143, expected=5.000000
# predicted=7.857143, expected=7.000000
# predicted=8.071429, expected=4.000000
# predicted=7.928571, expected=5.000000
# predicted=7.642857, expected=8.000000
# predicted=7.500000, expected=3.000000
# predicted=7.142857, expected=4.000000
# predicted=7.071429, expected=8.000000
# predicted=7.071429, expected=10.000000
# predicted=6.928571, expected=8.000000
# predicted=6.928571, expected=4.000000
# predicted=6.785714, expected=7.000000
# predicted=6.500000, expected=10.000000
# predicted=6.500000, expected=4.000000
# predicted=6.214286, expected=4.000000
# predicted=6.142857, expected=7.000000
# predicted=6.142857, expected=7.000000
# predicted=6.357143, expected=11.000000
# predicted=6.785714, expected=12.000000
# predicted=7.071429, expected=13.000000
# predicted=7.785714, expected=6.000000
# predicted=7.928571, expected=8.000000
# predicted=7.928571, expected=5.000000
# predicted=7.571429, expected=5.000000
# predicted=7.357143, expected=20.000000
# predicted=8.500000, expected=4.000000
# predicted=8.285714, expected=6.000000
# predicted=8.000000, expected=2.000000
# predicted=7.857143, expected=4.000000
# predicted=7.857143, expected=6.000000
# predicted=7.785714, expected=7.000000
# predicted=7.785714, expected=9.000000
# predicted=7.642857, expected=6.000000
# predicted=7.214286, expected=17.000000
# predicted=7.500000, expected=2.000000
# predicted=7.214286, expected=11.000000
# predicted=7.428571, expected=6.000000
# predicted=7.500000, expected=6.000000
# predicted=7.571429, expected=6.000000
# predicted=6.571429, expected=7.000000
# predicted=6.785714, expected=11.000000
# predicted=7.142857, expected=8.000000
# predicted=7.571429, expected=7.000000
# predicted=7.785714, expected=12.000000
# predicted=8.214286, expected=18.000000
# predicted=9.000000, expected=6.000000
# predicted=8.785714, expected=4.000000
# predicted=8.642857, expected=14.000000
# predicted=8.428571, expected=8.000000
# predicted=8.857143, expected=8.000000
# predicted=8.642857, expected=10.000000
# predicted=8.928571, expected=10.000000
# predicted=9.214286, expected=9.000000
# predicted=9.428571, expected=5.000000
# predicted=9.285714, expected=10.000000
# predicted=9.214286, expected=9.000000
# predicted=9.285714, expected=3.000000
# predicted=9.000000, expected=18.000000
# predicted=9.428571, expected=11.000000
# predicted=8.928571, expected=7.000000
# predicted=9.000000, expected=8.000000
# predicted=9.285714, expected=11.000000
# predicted=9.071429, expected=9.000000
# predicted=9.142857, expected=5.000000
# predicted=8.928571, expected=12.000000
# predicted=9.071429, expected=7.000000
# predicted=8.857143, expected=8.000000
# predicted=8.785714, expected=8.000000
# predicted=9.000000, expected=7.000000
# predicted=8.785714, expected=5.000000
# predicted=8.500000, expected=4.000000
# predicted=8.571429, expected=5.000000
# predicted=7.642857, expected=2.000000

# %%
# Métricas para mensurar o modelo
print('Erro médio absoluto (MSE):',
      round(mean_absolute_error(testMM, modelo2), 3))
print('Raiz do erro médio quadrado (RMSE):',
      round(mean_squared_error(testMM, modelo2)**0.5, 3))
print('Soma quadratica dos erros (SSE):',
      round(np.sum((modelo2 - testMM)**2), 3))
print('Erro medio percentual absoluto (MAPE):',
      np.mean(np.abs((testMM - modelo2)/testMM))*100)
# Out:
# Erro médio absoluto (MSE): 2.664
# Raiz do erro médio quadrado (RMSE): 3.387
# Soma quadratica dos erros (SSE): 4186.837
# Erro medio percentual absoluto (MAPE): inf

# %%
plt.plot(testMM, color = 'blue', label = 'Real')
plt.plot(modelo2, color = 'red', label = 'Previsto')
plt.title('Modelo 2 - Suavização de Media Móvel (14 passos a frente)')
plt.xlabel('Tempo')
plt.ylabel('Vitimas de acidentes')
plt.legend()
plt.show()

# %% [markdown]
# ### Modelo 3 - Auto Arima
#
# * Basicamente, o ARIMA utiliza dados passados para prever o futuro, usando dois principais recursos: a autocorrelação e médias móveis. (https://medium.com/techbloghotmart/dicas-para-criar-um-modelo-de-previs%C3%A3o-de-s%C3%A9ries-temporais-d4bb2e32e148)
# * o Auto_arima retorna o melhor ajuste ao modelo ARIMA

# %%
# Definindo o index como cada dia da série, mas sem perder o dado inicial (train)
trainD = train.set_index('data')
auto_arima = pm.auto_arima(trainD, start_p=0, start_q=0,
                            max_p=4, max_q=4,
                            start_P=0, start_Q=0, seasonal=False,
                            trace=True,
                            error_action='ignore',
                            suppress_warnings=True,
                            stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=8843.249, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=7656.859, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=8279.770, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=7354.215, Time=0.07 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=7203.091, Time=0.10 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=7121.325, Time=0.16 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=6889.316, Time=0.60 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=6887.782, Time=0.49 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=6885.910, Time=0.33 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=6886.395, Time=0.34 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=6890.350, Time=0.33 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=6885.868, Time=0.38 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=8010.715, Time=0.10 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=6887.823, Time=0.62 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=7825.991, Time=0.17 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=6889.868, Time=0.49 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=6878.342, Time=1.17 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=6884.479, Time=0.19 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=6884.820, Time=0.45 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=6886.887, Time=1.14 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=6879.443, Time=1.38 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=6882.917, Time=0.10 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=6884.054, Time=0.24 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=6879.787, Time=0.99 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=6879.037, Time=1.92 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0] intercept
# Total fit time: 11.961 seconds

# %%
# Predição do modelo
modelo3 = pd.DataFrame(auto_arima.predict(n_periods = 365), index= test.index)
modelo3.columns = ['previsão_acidentes']
modelo3
# Out:
#       previsão_acidentes
# 1310            6.070116
# 1311            5.843750
# 1312            5.887822
# 1313            5.925995
# 1314            5.959060
# ...                  ...
# 1670            6.173055
# 1671            6.173055
# 1672            6.173055
# 1673            6.173055
# 1674            6.173055
#
# [365 rows x 1 columns]

# %%
# Métricas para mensurar o modelo
print('Erro médio absoluto (MSE):',
      round(mean_absolute_error(test.set_index('data'), modelo3), 3))
print('Raiz do erro médio quadrado (RMSE):',
      round(mean_squared_error(test.set_index('data'), modelo3)**0.5, 3))
print('Soma quadratica dos erros (SSE):',
      round(np.sum((modelo3.previsão_acidentes - test.vitimas_total)**2), 3))
print('Erro medio percentual absoluto (MAPE):',
      np.mean(np.abs((test.vitimas_total - modelo3.previsão_acidentes)/test.vitimas_total))*100)
# Out:
# Erro médio absoluto (MSE): 2.623
# Raiz do erro médio quadrado (RMSE): 3.365
# Soma quadratica dos erros (SSE): 4132.309
# Erro medio percentual absoluto (MAPE): inf

# %%
plt.plot(test.vitimas_total, color = 'blue', label = 'Real')
plt.plot(modelo3, color = 'red', label = 'Previsto')
plt.title('Modelo 3 - Auto Arima')
plt.xlabel('Tempo')
plt.ylabel('Vitimas de acidentes')
plt.legend()
plt.show()

# %% [markdown]
# ### Modelo 4 - Random Forest
#
# * Em português, Random Forest significa floresta aleatória. Este nome explica muito bem o funcionamento do algoritmo, que irá criar muitas árvores de decisão, de maneira aleatória, formando o que podemos enxergar como uma floresta, onde cada árvore será utilizada na escolha do resultado final. (https://didatica.tech/o-que-e-e-como-funciona-o-algoritmo-randomforest/#:~:text=Em%20portugu%C3%AAs%2C%20Random%20Forest%20significa,na%20escolha%20do%20resultado%20final.)

# %%
# Para esse modelo é necessário definir bases de treino de teste (separando em variáveis x e y), além da criação de variável dummy
df_md4 = df.copy()
df_md4['data'] = pd.to_datetime(df_md4['data'], format='%Y-%m-%d')
df_md4['month'] = df_md4['data'].dt.month
dummy = pd.get_dummies(df_md4['month'])
df_md4 = pd.concat([df_md4, dummy], axis=1)

# %%
# Treino e teste
train = df_md4[(df_md4['data'] >= '2015-06-01') & (df_md4['data'] <= '2018-12-31')]
train = train.drop(['data'], axis=1)
train = train.reset_index(drop=True)

test = df_md4[(df_md4['data'] >= '2019-01-01') ]
test = test.drop(['data'], axis=1)
test = test.reset_index(drop=True)

# %%
# Definindo x e y para test
test_md4_x = test.loc[:, test.columns != 'vitimas_total']
test_md4_y = test['vitimas_total']

# %%
# Definindo x e y para train
train_md4_x = train.loc[:, train.columns != 'vitimas_total']
train_md4_y = train['vitimas_total']

# %%
# Modelagem e previsão
rfe = RFE(estimator = RandomForestRegressor(n_estimators = 100, random_state = 1), n_features_to_select = 4) # https://machinelearningmastery.com/rfe-feature-selection-in-python/
fit = rfe.fit(train_md4_x, train_md4_y)
modelo4 = fit.predict(test_md4_x)

# %%
modelo4
# Out:
# array([6.24841328, 6.24841328, 6.24841328, 6.24841328, 6.24841328,
#        6.24841328, 6.24841328, 6.24841328, 6.24841328, 6.24841328,
#        6.24841328, 6.24841328, 6.24841328, 6.24841328, 6.24841328,
#        6.24841328, 6.24841328, 6.24841328, 6.24841328, 6.24841328,
#        6.24841328, 6.24841328, 6.24841328, 6.24841328, 6.24841328,
#        6.24841328, 6.24841328, 6.24841328, 6.24841328, 6.24841328,
#        6.24841328, 5.65500546, 5.65500546, 5.65500546, 5.65500546,
#        5.65500546, 5.65500546, 5.65500546, 5.65500546, 5.65500546,
#        5.65500546, 5.65500546, 5.65500546, 5.65500546, 5.65500546,
#        5.65500546, 5.65500546, 5.65500546, 5.65500546, 5.65500546,
#        5.65500546, 5.65500546, 5.65500546, 5.65500546, 5.65500546,
#        5.65500546, 5.65500546, 5.65500546, 5.65500546, 5.85186761,
#        5.85186761, 5.85186761, 5.85186761, 5.85186761, 5.85186761,
#        5.85186761, 5.85186761, 5.85186761, 5.85186761, 5.85186761,
#        5.85186761, 5.85186761, 5.85186761, 5.85186761, 5.85186761,
#        5.85186761, 5.85186761, 5.85186761, 5.85186761, 5.85186761,
#        5.85186761, 5.85186761, 5.85186761, 5.85186761, 5.85186761,
#        7.23648851, 7.23648851, 7.23648851, 7.23648851, 7.23648851,
#        7.23648851, 7.23648851, 7.23648851, 7.23648851, 7.23648851,
#        7.23648851, 7.23648851, 7.23648851, 7.23648851, 6.93304018,
#        6.93304018, 6.93304018, 6.93304018, 6.93304018, 6.93304018,
#        6.93304018, 6.93304018, 6.93304018, 6.93304018, 6.93304018,
#        6.93304018, 6.93304018, 6.93304018, 6.93304018, 6.93304018,
#        6.93304018, 6.93304018, 6.93304018, 6.93304018, 6.93304018,
#        6.93304018, 6.93304018, 6.93304018, 6.93304018, 6.93304018,
#        6.93304018, 6.93304018, 6.93304018, 6.93304018, 6.45302416,
#        6.45302416, 6.45302416, 6.45302416, 6.45302416, 6.45302416,
#        6.45302416, 6.45302416, 6.45302416, 6.45302416, 6.45302416,
#        6.45302416, 6.45302416, 6.45302416, 6.45302416, 6.45302416,
#        6.45302416, 6.45302416, 6.45302416, 6.45302416, 6.45302416,
#        6.45302416, 6.45302416, 6.45302416, 6.45302416, 6.45302416,
#        6.45302416, 6.45302416, 6.45302416, 6.45302416, 6.45302416])

# %%
# Métricas para mensurar o modelo
print('Erro médio absoluto (MSE):',
      round(mean_absolute_error(test_md4_y, modelo4), 3))
print('Raiz do erro médio quadrado (RMSE):',
      round(mean_squared_error(test_md4_y, modelo4)**0.5, 3))
print('Soma quadratica dos erros (SSE):',
      round(np.sum((modelo4 - test_md4_y)**2), 3))
print('Erro medio percentual absoluto (MAPE):',
      np.mean(np.abs((test_md4_y - modelo4)/test_md4_y))*100)
# Out:
# Erro médio absoluto (MSE): 2.614
# Raiz do erro médio quadrado (RMSE): 3.343
# Soma quadratica dos erros (SSE): 4079.01
# Erro medio percentual absoluto (MAPE): inf

# %%
plt.plot(test_md4_y, color = 'blue', label = 'Real')
plt.plot(modelo4, color = 'red', label = 'Previsto')
plt.title('Modelo 4 - Random Forest')
plt.xlabel('Tempo')
plt.ylabel('Vitimas de acidentes')
plt.legend()
plt.show()

# %% [markdown]
# ### Modelo 5 - RNN (Redes Neurais) [LSTM]
#
# * Uma rede neural recorrente ( RNN ) é uma classe de redes neurais artificiais onde as conexões entre os nós formam um gráfico direcionado ao longo de uma sequência temporal. Isso permite que ele exiba um comportamento dinâmico temporal. (https://stringfixer.com/pt/Recurrent_neural_networks)

# %%
# Para facilitar os próximos passos e seguindo as instruções do desafios:
# separação do material em treino (train) e teste (test)
train = df[(df['data'] >= '2015-06-01') & (df['data'] <= '2018-12-31')]
train['data'] =  pd.to_datetime(train['data'], format='%Y-%m-%d')

test = df[(df['data'] >= '2019-01-01') ]
test['data'] =  pd.to_datetime(test['data'], format='%Y-%m-%d')

# %%
train
# Out:
#            data  vitimas_total
# 0    2015-06-01            6.0
# 1    2015-06-02            8.0
# 2    2015-06-03            4.0
# 3    2015-06-04            4.0
# 4    2015-06-05            8.0
# ...         ...            ...
# 1305 2018-12-27            9.0
# 1306 2018-12-28            4.0
# 1307 2018-12-29            4.0
# 1308 2018-12-30            6.0
# 1309 2018-12-31            2.0
#
# [1310 rows x 2 columns]

# %%
# Definindo dados de treino e teste e padronizando
sc = StandardScaler()
train = train.drop(['data'], axis=1)
train = train.reset_index(drop=True)
training_set_scaled = sc.fit_transform(train)

# %%
training_set_scaled
# Out:
# array([[-0.06856173],
#        [ 0.53021072],
#        [-0.66733418],
#        ...,
#        [-0.66733418],
#        [-0.06856173],
#        [-1.26610663]])

# %%
# Criando as estruturas necessárias (vazias por enquanto...)
X_train = [] 
y_train = []
n_timestep = 14 #tomando como base a análise de auto correlação presente no notebook 1

# %%
# Populando as estruturas
for i in range( n_timestep, len(training_set_scaled) ): 
    X_train.append( training_set_scaled[i-n_timestep:i, 0] ) # Linhas 0 a 13 (Coluna 0)
    y_train.append( training_set_scaled[i, 0] ) # 14
print( len(X_train[0]), len(X_train[1]) )
# Out:
# 14 14

# %%
print( X_train[0], y_train[0] )
# Out:
# [-0.06856173  0.53021072 -0.66733418 -0.66733418  0.53021072  2.32652807
#  -0.36794796  1.12898317  1.72775562 -0.96672041  1.4283694   0.53021072
#  -0.06856173 -1.26610663] 2.6259142969371023

# %%
print( X_train[1], y_train[1] )
# Out:
# [ 0.53021072 -0.66733418 -0.66733418  0.53021072  2.32652807 -0.36794796
#   1.12898317  1.72775562 -0.96672041  1.4283694   0.53021072 -0.06856173
#  -1.26610663  2.6259143 ] -0.9667204069664005

# %%
X_train[2]
# Out:
# array([-0.66733418, -0.66733418,  0.53021072,  2.32652807, -0.36794796,
#         1.12898317,  1.72775562, -0.96672041,  1.4283694 ,  0.53021072,
#        -0.06856173, -1.26610663,  2.6259143 , -0.96672041])

# %%
# Para alimentar na rede, transforma-se em numpy array    
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (1296, 14)

# %%
# Passa-se para a RNN mais de um indicador para prever a saída. Nesse caso tem-se somente 1

# Fazendo no X_train, primeiro parâmetro do método reshape, sendo o segundo parâmetro o novo formato linhas de X, colunas de X e a 3ª dimensão
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (1296, 14, 1)

# %%
# Modelo
# Inicializando a  RNN
myRNN = Sequential()

# %%
# Adicionando a primeira camada de LSTM. 
# Units: número de células LSTM: 
# A camada será formada por várias células (unidades) LSTM paralelas, estruturalmente idênticas, cada uma aprendendo algo específico
# Return sequences: true indica que vamos empilhar outra camada em cima
# Input Shape: (nº de timesteps, número de indicadores)
myRNN.add( GRU(units = 14, return_sequences = True, input_shape = (X_train.shape[1], 1)) )

# %%
# Adicionando uma camada regularizadora (para evitar overfitting)
myRNN.add(Dropout(0.2))

# %%
# Adicionando uma segunda camada, conforme a primeira (sem o input_shape)
myRNN.add(GRU(units = 22, return_sequences = True))
myRNN.add(Dropout(0.2))

# %%
# Adicionando uma terceira camada... Como vou parar de empilhar, não preciso especificar o parâmetro return_sequences
myRNN.add(GRU(units = 22))
myRNN.add(Dropout(0.2))

# %%
# Camada de saida - E a função de ativação? Nãoé necessário pois está se prevendo um valor
# Em casos como este, de regressão, não precisamos usar uma função de ativação na última camada.
myRNN.add(Dense(units = 1))

# %%
# RMSprop é bem recomendado para RNN
myRNN.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
myRNN.fit(X_train, y_train, epochs = 100, batch_size = 30)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 6s 17ms/step - loss: 1.0051
# Epoch 2/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.
100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9383
# Epoch 99/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.9489
# Epoch 100/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.9502

# %% [markdown]
# * Previsão

# %%
# Ajustando os dados
df = df.drop(['data'], axis=1)
df = df.reset_index(drop=True)

test = test.drop(['data'], axis=1)
test = test.reset_index(drop=True)

# %%
len(df)
# Out:
# 1675

# %%
# Para cada dia D temos que pegar os n anteriores, definidos por n_timestep
# Vamos passar n_timesteps anteriores a este ponto, então subtraímos n_timestep
# len(dataset_total) - len(dataset_test) - n_timestep define a fronteira inferior. 
# define a fronteira superior: define a superior
inputs = df[ len(df) - len(test) - n_timestep:].values # tornando um array
inputs.shape
# Out:
# (379, 1)

# %%
# Feature scaling para os valores... 
inputs = sc.transform(inputs)

# %%
# Preparando os inputs para submeter para previsoes. Semelhante ao que foi realizado para o treinamento...
X_test = [] # vai receber os inputs...
for i in range(n_timestep, n_timestep+len(test)):
    X_test.append(inputs[i-n_timestep:i, 0])

# %%
# Vamos agora ajustar para enviar para a rede...
# Se quiser relembrar os movitos, ver os comentários que fizemos em cima para o X_train...
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
modelo5 = myRNN.predict(X_test)
# Out:
# 12/12 [==============================] - 1s 6ms/step

# %%
modelo5
# Out:
# array([[-4.42093387e-02],
#        [-1.19814321e-01],
#        [-6.20498955e-02],
#        [-1.00530967e-01],
#        [-7.24176094e-02],
#        [-2.24619210e-02],
#        [-1.86555423e-02],
#        [-1.14614949e-01],
#        [-6.28377646e-02],
#        [-8.84629637e-02],
#        [-6.74694479e-02],
#        [-8.15665051e-02],
#        [-1.46671563e-01],
#        [-6.11966625e-02],
#        [-4.97602709e-02],
#        [-7.59622827e-02],
#        [-9.91654471e-02],
#        [-1.07948259e-01],
#        [-7.72724003e-02],
#        [-1.27368122e-01],
#        [-9.66077596e-02],
#        [-1.70399174e-01],
#        [-9.30548459e-02],
#        [-7.92240128e-02],
#        [-8.90330747e-02],
#        [-1.46655589e-01],
#        [-7.06452802e-02],
#        [-7.38140345e-02],
#        [-4.96138558e-02],
#        [-9.42800641e-02],
#        [-1.34329751e-01],
#        [-5.74191511e-02],
#        [-1.00111037e-01],
#        [-5.54969311e-02],
#        [-7.72247612e-02],
#        [-1.35684267e-01],
#        [-9.40702632e-02],
#        [-7.92113394e-02],
#        [-2.82990523e-02],
#        [-3.33935805e-02],
#        [ 1.02265656e-01],
#        [ 9.25266892e-02],
#        [-1.23157622e-02],
#        [-1.50230005e-01],
#        [-3.18481550e-02],
#        [ 5.18033653e-02],
#        [-1.27772883e-01],
#        [ 8.01388144e-01],
#        [ 1.82030749e+00],
#        [ 1.09529257e+00],
#        [ 5.98020613e-01],
#        [ 3.45122963e-01],
#        [ 1.37805089e-01],
#        [ 5.89664243e-02],
#        [ 7.28752166e-02],
#        [ 1.65467262e-01],
#        [-5.62292337e-02],
#        [-3.85291912e-02],
#        [-6.56417981e-02],
#        [-3.82073969e-02],
#        [-1.05142251e-01],
#        [-9.04102996e-02],
#        [ 6.6022205],
#        [ 7.877454 ],
#        [ 7.228716 ],
#        [ 6.583138 ],
#        [ 6.6349235],
#        [ 7.2871075],
#        [ 6.7334423],
#        [ 6.249557 ],
#        [ 6.49101  ],
#        [ 6.682576 ],
#        [ 6.6058173],
#        [ 6.203624 ],
#        [ 6.1470065],
#        [ 5.9605036],
#        [ 6.095725 ],
#        [ 6.1144857],
#        [ 6.7291436],
#        [ 6.548261 ],
#        [ 6.46384  ],
#        [ 6.3275933],
#        [ 6.147741 ],
#        [ 5.8558154],
#        [ 5.7238674],
#        [ 6.7423716],
#        [ 8.65066  ],
#        [ 7.678442 ],
#        [ 6.9656577],
#        [ 6.5366054],
#        [ 6.920372 ],
#        [ 6.6482673],
#        [ 6.2440305],
#        [ 6.4258313],
#        [ 8.033651 ],
#        [ 8.2191925],
#        [ 7.6304297],
#        [ 7.106636 ],
#        [ 6.528536 ],
#        [ 6.5508757],
#        [ 6.6630635],
#        [ 6.213115 ],
#        [ 5.9449406],
#        [ 6.0164742],
#        [ 6.4018536],
#        [ 6.186753 ],
#        [ 6.09351  ],
#        [ 6.3386025],
#        [ 6.3201475],
#        [ 6.1600156],
#        [ 6.1361055],
#        [ 5.953859 ],
#        [ 5.7773404],
#        [ 5.525329 ],
#        [ 7.115682 ],
#        [ 8.398682 ],
#        [ 7.953191 ],
#        [ 7.5299864],
#        [ 6.822749 ],
#        [ 5.869596 ],
#        [ 4.8022594],
#        [ 4.177292 ],
#        [ 4.447786 ],
#        [ 4.6571326],
#        [ 6.3907337],
#        [ 8.668281 ],
#        [11.214777 ],
#        [ 7.9959846],
#        [ 6.466153 ],
#        [ 5.1971984],
#        [ 4.8111   ],
#        [ 6.857841 ],
#        [ 4.8959394],
#        [ 6.790535 ],
#        [ 7.559731 ],
#        [ 7.4915547],
#        [ 9.7882595],
#        [ 8.641134 ],
#        [ 6.1403832],
#        [ 7.4128284],
#        [11.46582  ],
#        [ 7.9388523],
#        [ 5.73965  ],
#        [ 5.24179  ],
#        [ 6.5484147],
#        [ 8.277201 ],
#        [ 9.523244 ],
#        [10.365493 ],
#        [ 8.446888 ],
#        [ 5.921456 ],
#        [ 8.01054  ],
#        [ 8.3496275],
#        [ 5.336421 ],
#        [ 6.1425476],
#        [10.090994 ],
#        [ 8.020912 ],
#        [ 6.7945395],
#        [ 9.487322 ],
#        [ 8.618071 ],
#        [ 6.3559513],
#        [ 6.2930593],
#        [ 8.091777 ],
#        [ 9.586466 ],
#        [ 9.965563 ],
#        [ 9.057658 ],
#        [ 7.71904  ]], dtype=float32)

# %%
# Métricas para mensurar o modelo
print('Erro médio absoluto (MSE):',
      round(mean_absolute_error(test, modelo5), 3))
print('Raiz do erro médio quadrado (RMSE):',
      round(mean_squared_error(test, modelo5)**0.5, 3))
print('Soma quadratica dos erros (SSE):',
      round(np.sum((modelo5 - test)**2), 3))
print('Erro medio percentual absoluto (MAPE):',
      np.mean(np.abs((test - modelo5)/test))*100)
# Out:
# Erro médio absoluto (MSE): 2.638
# Raiz do erro médio quadrado (RMSE): 3.353
# Soma quadratica dos erros (SSE): vitimas_total    4103.163
# dtype: float64
# Erro medio percentual absoluto (MAPE): vitimas_total    inf
# dtype: float64

# %%
plt.plot(test, color = 'blue', label = 'Real')
plt.plot(modelo5, color = 'red', label = 'Previsto')
plt.title('Modelo 5 - RNN')
plt.xlabel('Tempo')
plt.ylabel('Vitimas de acidentes')
plt.legend()
plt.show()

# %% [markdown]
# ## Resultados dos modelos

# %%
img = mpimg.imread(r'C:\Users\rapha\Documents\desafio_forecast\notebook\imagem\tabela_metricasxmodelos.PNG')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# * Tomando como parâmetro os resultados para os testes aplicados em cada modelo, a escolha seria pelo modelo 3 (Auto Arima), que apresentou as menores métricas. Porém olhando os valores previstos, em grande maioria, são iguais (repetidos) a partir de um determinado período. Não que seja um problema, mas foge um pouco do dinamismo presente nos dados reais de acidentes. Por isso eu teria algumas ressalvas, mas de toda forma, é uma boa escolha de modelo para previsões.
# * Com base no cenário dos 5 modelos, todos apresentam métricas bem parecidas, logo seriam ótimas escolhas. Contudo, se eu estivesse numa situação onde precisa-se explicar para alguém com pouco conhecimento, quando se trata de modelagem/previsão, o modelo 1 é mais fácil de ser explicado e poderia trazer um entendimento mais objetivo para solucionar o problema. Mas o modelo 5 me agrada bastante por ser mais “robusto” e ter mais etapas até se chegar nas previsões.
# * Creio que pensaria melhor no contexto onde a metodologia deveria ser apresentada, mas fico com os modelos 3 e 5.

# %% [markdown]
# #### Pergunta extra: : É possível adicionar outras variáveis para ajudar no processo de previsão? Quais? melhoraram os resultados?

# %% [markdown]
# * Quando falamos de processo de previsão, na maioria dos casos, é sempre viável e plausível a incorporação de mais variáveis. Nesse contexto, com um tratamento prévio dos dados, as variáveis que descrevem por qual veículo (moto, carro etc) poderia ser mais um incremento pro modelo, talvez tornando uma variável dummy (sim e não) ou a partir delas, contabilizar as vítimas.
# * A variável vítima fatal ou não, me pareceu interessante e poderia trazer mais profundidade para a interpretação final das análises
# * Geralmente utilizam-se variáveis demográficas, que em geral são interessantes e valeria avaliar a correlação delas com os dados de vítimas para averiguar se vale a pena ou não, incorporar no modelo. Além de dados de clima/tempo (precipitação, chuvas etc).

# %% [markdown]
# ###### Referências

# %%
# https://ivanildo-batista13.medium.com/modelos-de-suaviza%C3%A7%C3%A3o-exponencial-em-python-c495a21d230b
# https://machinelearningmastery.com/moving-average-smoothing-for-time-series-forecasting-python/
# https://datapane.com/reports/9Armyrk/arima-for-hierarchical-time-series-forecasting/#:~:text=The%20Python%20framework%20scikit%2Dhts,Top%2DDown%2C%20OLS%20etc.
# https://github.com/SushmithaPulagam/TimeSeries_Auto-ARIMA/blob/master/TimeSeries_AutoARIMA.py
# # https://www.analyticsvidhya.com/blog/2021/06/random-forest-for-time-series-forecasting/
# https://www.statology.org/sst-ssr-sse-in-python/
# https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
# https://www.askpython.com/python/examples/mape-mean-absolute-percentage-error#:~:text=What%20is%20MAPE%3F,termed%20by%20the%20model%20evaluation.
